# %%
# this is a dev file (helper), can be deleted savely
import os
os.chdir("/home/thesis/marx/wilson_gen/")
os.listdir()
# Out:
# ['stablediffusion',
#  'scripts',
#  'WILSON_WIP',
#  'README.md',
#  'generative_models',
#  '.git',
#  'Web-WILSS',
#  'WILSON',
#  '.gitignore',
#  'LICENSE']

# %%
for entry in os.listdir("WILSON"):
    print(entry)
    os.system(f"diff -r WILSON/{entry} WILSON_WIP/{entry}")
    print("------------------------------------------------------------")
# Out:
# docs
# ------------------------------------------------------------
# logs_backup
# ------------------------------------------------------------
# train.py
# ------------------------------------------------------------
# utils
# ------------------------------------------------------------
# wandb
# diff -r WILSON/wandb/debug-internal.log WILSON_WIP/wandb/debug-internal.log
# 1,8c1,18
# < {"time":"2024-11-25T17:57:18.789028575+01:00","level":"INFO","msg":"using version","core version":"0.18.7"}
# < {"time":"2024-11-25T17:57:18.789054416+01:00","level":"INFO","msg":"created symlink","path":"/home/thesis/marx/wilson_gen/WILSON/wandb/run-20241125_175718-pwjjluqu/logs/debug-core.log"}
# < {"time":"2024-11-25T17:57:18.896098831+01:00","level":"INFO","msg":"created new stream","id":"pwjjluqu"}
# < {"time":"2024-11-25T17:57:18.896146167+01:00","level":"INFO","msg":"stream: started","id":"pwjjluqu"}
# ...
